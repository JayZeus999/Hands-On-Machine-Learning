# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1, 2, 4, 9, 5, 3])
plt.show()

# %% [markdown]
# The axes automatically match the extent of the data.
#
# We would like to give the graph a bit more room, so let's call the axis function to change the extent of each axis [xmin, xmax, ymin, ymax].

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3])
plt.axis([-4, 6, 0, 7])
plt.show()

# %% [markdown]
# Now, let's plot a mathematical function. We use NumPy's linspace function to create an array x containing 500 floats ranging from -2 to 2, then we create a second array y computed as the square of x

# %%
x = np.linspace(-2, 2, 500)
y = x**2

plt.plot(x, y)
plt.show()
